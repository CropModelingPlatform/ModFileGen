# %% [markdown]
# # STICS Converter - Run Main Function
#
# This notebook demonstrates how to run the STICS converter main() function to generate STICS input files from master database.

# %% [markdown]
# ## 1. Import Required Modules

# %%
import os
import sys
from pathlib import Path
from modfilegen import GlobalVariables
from modfilegen.Converter.SticsConverter.sticsconverter import main

# %% [markdown]
# ## 2. Configure Paths and Global Variables
#
# Set the required paths for:
# - `dbMasterInput`: Path to the master input SQLite database
# - `dbModelsDictionary`: Path to the models dictionary database
# - `directorypath`: Output directory for generated STICS files
# - `pltfolder`: Path to cultivar/plant parameter files
# - Other configuration parameters

# %%
# Base paths derived from the repository root, not from the kernel cwd
cwd = Path.cwd().resolve()
candidates = [cwd, cwd.parent]
repo_root = next(
    (
        path
        for path in candidates
        if (path / "tests" / "data").exists() and (path / "src" / "modfilegen").exists()
    ),
    None,
)
if repo_root is None:
    raise FileNotFoundError(
        f"Could not locate the ModFileGen repository from cwd={cwd}."
    )

data_dir = repo_root / "tests" / "data"
output_dir = repo_root / "tests" / "output"
temp_dir = output_dir / "temp"
package_dir = repo_root / "src" / "modfilegen"

# Create output directories if they don't exist
output_dir.mkdir(parents=True, exist_ok=True)
temp_dir.mkdir(parents=True, exist_ok=True)
print(f"Kernel cwd: {cwd}")
print(f"Repo root: {repo_root}")
print(f"Output directory: {output_dir.resolve()}")

# Database paths
master_input_db = data_dir / "MasterInput.db"
models_dict_db = data_dir / "ModelsDictionaryArise.db"

# Cultivar/plant parameters folder
cultivars_folder = data_dir / "cultivars" / "stics"

# Configuration
n_threads = 4  # Number of parallel threads
n_parts = 1    # Number of data partitions
dt = 0        # choice to delete intermediate files 0 (no) or 1 (yes)

# Verify files exist
print("Checking files...")
print(f"Master Input DB exists: {master_input_db.exists()}")
print(f"Models Dict DB exists: {models_dict_db.exists()}")
print(f"Cultivars folder exists: {cultivars_folder.exists()}")
# Out:
# Kernel cwd: /mnt/d/Mes Donnees/TCMP/github/ModFileGen/notebooks
# Repo root: /mnt/d/Mes Donnees/TCMP/github/ModFileGen
# Output directory: /mnt/d/Mes Donnees/TCMP/github/ModFileGen/tests/output
# Checking files...
# Master Input DB exists: True
# Models Dict DB exists: True
# Cultivars folder exists: True

# %% [markdown]
# ## 3. Set Global Variables
#
# Configure the GlobalVariables dictionary that will be used by the converter.

# %%
# Set global variables
GlobalVariables["dbMasterInput"] = str(master_input_db)
GlobalVariables["dbModelsDictionary"] = str(models_dict_db)
GlobalVariables["directorypath"] = str(output_dir)
GlobalVariables["pltfolder"] = str(cultivars_folder)
GlobalVariables["nthreads"] = n_threads
GlobalVariables["dt"] = dt
GlobalVariables["parts"] = n_parts
GlobalVariables["tempDir"] = str(temp_dir)
GlobalVariables["package"] = str(package_dir)

print("Global Variables configured:")
for key, value in GlobalVariables.items():
    print(f"  {key}: {value}")
# Out:
# Global Variables configured:
#   storeNumMinSimu: 0
#   storeNumMaxSimu: 0
#   storeKeyDataN: 0
#   dbMasterInput: /mnt/d/Mes Donnees/TCMP/github/ModFileGen/tests/data/MasterInput.db
#   dbModelsDictionary: /mnt/d/Mes Donnees/TCMP/github/ModFileGen/tests/data/ModelsDictionaryArise.db
#   dbCelsius:
#   dt: 0
#   ori_MI:
#   parts: 1
#   tempDir: /mnt/d/Mes Donnees/TCMP/github/ModFileGen/tests/output/temp
#   package: /mnt/d/Mes Donnees/TCMP/github/ModFileGen/src/modfilegen
#   directorypath: /mnt/d/Mes Donnees/TCMP/github/ModFileGen/tests/output
#   pltfolder: /mnt/d/Mes Donnees/TCMP/github/ModFileGen/tests/data/cultivars/stics
#   nthreads: 4

# %% [markdown]
# ## 4. Run the STICS Converter
#
# Execute the main() function to generate STICS input files.
#
# **Note**: This process can take some time depending on:
# - Number of simulations in the database
# - Number of threads configured
# - System resources

# %%
# Run the converter
print("Starting STICS conversion...")
print("=" * 60)

try:
    main()
    print("\n" + "=" * 60)
    print("✅ STICS conversion completed successfully!")
except Exception as e:
    print("\n" + "=" * 60)
    print(f"❌ Error during conversion: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Starting STICS conversion...
# ============================================================
# dbMasterInput: /mnt/d/Mes Donnees/TCMP/github/ModFileGen/tests/data/MasterInput.db
# dbModelsDictionary: /mnt/d/Mes Donnees/TCMP/github/ModFileGen/tests/data/ModelsDictionaryArise.db
# Indexes created successfully!
# 📊 Total simulations to process: 808
# Processing 4 chunks...
# Iteration 0Iteration 0
# Iteration 0
#
# Iteration 0
# Iteration 1
# Iteration 1
# Iteration 1
# Iteration 1
# Iteration 2
# Iteration 2
# Iteration 2
# Iteration 2
# Iteration 3
# Iteration 3
# Iteration 3
# Iteration 3
# Iteration 4
# Iteration 4
# Iteration 4
# Iteration 4
# Iteration 5
# Iteration 5
# Iteration 5
# Iteration 5
# Iteration 6
# Iteration 6
# Iteration 6
# Iteration 6
# Iteration 7
# Iteration 7
# Iteration 7
# Iteration 8
# Iteration 7
# Iteration 8
# Iteration 8
# Iteration 8
# Iteration 9
# Iteration 9
# Iteration 9
# Iteration 9
# Iteration 10
# Iteration 10
# Iteration 10
# Iteration 10
# Iteration 11
# Iteration 11
# Iteration 11
# Iteration 11
# Iteration 12
# Iteration 12
# Iteration 12
# Iteration 12
# Iteration 13
# Iteration 13
# Iteration 13
# Iteration 13
# Iteration 14
# Iteration 14
# Iteration 14
# Iteration 14
# Iteration 15
# Iteration 15
# Iteration 15
# Iteration 16
# Iteration 15
# Iteration 16
# Iteration 16
# Iteration 16
# Iteration 17
# Iteration 17
# Iteration 17
# Iteration 17
# Iteration 18
# Iteration 18
# Iteration 18
# Iteration 18
# Iteration 19
# Iteration 19
# Iteration 19
# Iteration 19
# Iteration 20
# Iteration 20
# Iteration 20
# Iteration 20
# Iteration 21
# Iteration 21
# Iteration 21
# Iteration 21
# Iteration 22
# Iteration 22
# Iteration 22
# Iteration 23
# Iteration 22
# Iteration 23
# Iteration 23
# Iteration 24
# Iteration 23
# Iteration 24
# Iteration 24
# Iteration 24
# Iteration 25
# Iteration 25
# Iteration 25
# Iteration 25
# Iteration 26
# Iteration 26
# Iteration 26
# Iteration 26
# Iteration 27
# Iteration 27
# Iteration 27
# Iteration 28
# Iteration 27
# Iteration 28
# Iteration 28
# Iteration 28
# Iteration 29
# Iteration 29
# Iteration 29
# Iteration 30
# Iteration 29
# Iteration 30
# Iteration 30
# Iteration 31
# Iteration 30
# Iteration 31
# Iteration 31
# Iteration 32
# Iteration 31
# Iteration 32
# Iteration 32
# Iteration 32
# Iteration 33
# Iteration 33
# Iteration 33
# Iteration 34
# Iteration 33
# Iteration 34
# Iteration 34
# Iteration 35
# Iteration 34
# Iteration 35
# Iteration 35
# Iteration 36
# Iteration 35
# Iteration 36
# Iteration 36
# Iteration 36
# Iteration 37
# Iteration 37
# Iteration 37
# Iteration 38
# Iteration 38
# Iteration 37
# Iteration 38
# Iteration 39
# Iteration 38
# Iteration 39
# Iteration 39
# Iteration 40
# Iteration 39
# Iteration 40
# Iteration 40
# Iteration 41
# Iteration 40
# Iteration 41
# Iteration 41
# Iteration 42
# Iteration 41
# Iteration 42
# Iteration 42
# Iteration 43
# Iteration 42
# Iteration 43
# Iteration 43
# Iteration 44
# Iteration 43
# Iteration 44
# Iteration 44
# Iteration 44
# Iteration 45
# Iteration 45
# Iteration 45
# Iteration 46
# Iteration 46
# Iteration 45
# Iteration 46
# Iteration 47
# Iteration 46
# Iteration 47
# Iteration 47
# Iteration 48
# Iteration 47
# Iteration 48
# Iteration 48
# Iteration 49
# Iteration 48
# Iteration 49
# Iteration 49
# Iteration 50
# Iteration 49
# Iteration 50
# Iteration 50
# Iteration 51
# Iteration 50
# Iteration 51
# Iteration 51
# Iteration 52
# Iteration 51
# Iteration 52
# Iteration 52
# Iteration 53
# Iteration 52
# Iteration 53
# Iteration 53
# Iteration 54
# Iteration 54
# Iteration 53
# Iteration 54
# Iteration 55
# Iteration 54
# Iteration 55
# Iteration 55
# Iteration 56
# Iteration 55
# Iteration 56
# Iteration 56
# Iteration 57
# Iteration 56
# Iteration 57
# Iteration 57
# Iteration 58
# Iteration 57
# Iteration 58
# Iteration 58
# Iteration 59
# Iteration 58
# Iteration 59
# Iteration 59
# Iteration 60
# Iteration 59
# Iteration 60
# Iteration 60
# Iteration 61
# Iteration 60
# Iteration 61
# Iteration 61
# Iteration 62
# Iteration 62
# Iteration 61
# Iteration 62
# Iteration 63
# Iteration 62
# Iteration 63
# Iteration 63
# Iteration 64
# Iteration 63
# Iteration 64
# Iteration 64
# Iteration 65
# Iteration 64
# Iteration 65
# Iteration 65
# Iteration 66
# Iteration 65
# Iteration 66
# Iteration 66
# Iteration 67
# Iteration 66
# Iteration 67
# Iteration 67
# Iteration 68
# Iteration 67
# Iteration 68
# Iteration 68
# Iteration 69
# Iteration 68
# Iteration 69
# Iteration 69
# Iteration 70
# Iteration 70
# Iteration 69
# Iteration 70
# Iteration 71
# Iteration 70
# Iteration 71
# Iteration 71
# Iteration 72
# Iteration 71
# Iteration 72
# Iteration 72
# Iteration 73
# Iteration 72
# Iteration 73
# Iteration 73
# Iteration 74
# Iteration 73
# Iteration 74
# Iteration 74
# Iteration 75
# Iteration 74
# Iteration 75
# Iteration 75
# Iteration 76
# Iteration 75
# Iteration 76
# Iteration 76
# Iteration 76
# Iteration 77
# Iteration 77
# Iteration 77
# Iteration 78
# Iteration 77
# Iteration 78
# Iteration 78
# Iteration 79
# Iteration 78
# Iteration 79
# Iteration 79
# Iteration 80
# Iteration 79
# Iteration 80
# Iteration 80
# Iteration 81
# Iteration 80
# Iteration 81
# Iteration 81
# Iteration 82
# Iteration 81
# Iteration 82
# Iteration 82
# Iteration 83
# Iteration 82
# Iteration 83
# Iteration 83
# Iteration 84
# Iteration 83
# Iteration 84
# Iteration 84
# Iteration 84
# Iteration 85
# Iteration 85
# Iteration 85
# Iteration 86
# Iteration 86
# Iteration 85
# Iteration 86
# Iteration 87
# Iteration 86
# Iteration 87
# Iteration 87
# Iteration 88
# Iteration 87
# Iteration 88
# Iteration 88
# Iteration 89
# Iteration 88
# Iteration 89
# Iteration 89
# Iteration 90
# Iteration 89
# Iteration 90
# Iteration 90
# Iteration 91
# Iteration 90
# Iteration 91
# Iteration 91
# Iteration 92
# Iteration 91
# Iteration 92
# Iteration 92
# Iteration 92
# Iteration 93
# Iteration 93
# Iteration 93
# Iteration 94
# Iteration 93
# Iteration 94
# Iteration 94
# Iteration 95
# Iteration 94
# Iteration 95
# Iteration 95
# Iteration 96
# Iteration 95
# Iteration 96
# Iteration 96
# Iteration 96
# Iteration 97
# Iteration 97
# Iteration 97
# Iteration 98
# Iteration 97
# Iteration 98
# Iteration 98
# Iteration 99
# Iteration 98
# Iteration 99
# Iteration 99
# Iteration 100
# Iteration 99
# Iteration 100
# Iteration 100
# Iteration 100
# Iteration 101
# Iteration 101
# Iteration 101
# Iteration 102
# Iteration 101
# Iteration 102
# Iteration 102
# Iteration 103
# Iteration 102
# Iteration 103
# Iteration 103
# Iteration 104
# Iteration 103
# Iteration 104
# Iteration 104
# Iteration 105
# Iteration 104
# Iteration 105
# Iteration 105
# Iteration 106
# Iteration 105
# Iteration 106
# Iteration 106
# Iteration 107
# Iteration 106
# Iteration 107
# Iteration 107
# Iteration 108
# Iteration 107
# Iteration 108
# Iteration 108
# Iteration 108
# Iteration 109
# Iteration 109
# Iteration 109
# Iteration 110
# Iteration 109
# Iteration 110
# Iteration 110
# Iteration 111
# Iteration 110
# Iteration 111
# Iteration 111
# Iteration 112
# Iteration 111
# Iteration 112
# Iteration 112
# Iteration 113
# Iteration 112
# Iteration 113
# Iteration 113
# Iteration 114
# Iteration 113
# Iteration 114
# Iteration 114
# Iteration 115
# Iteration 114
# Iteration 115
# Iteration 115
# Iteration 116
# Iteration 115
# Iteration 116
# Iteration 116
# Iteration 116
# Iteration 117
# Iteration 117
# Iteration 117
# Iteration 118
# Iteration 117
# Iteration 118
# Iteration 118
# Iteration 119
# Iteration 118
# Iteration 119
# Iteration 119
# Iteration 120
# Iteration 119
# Iteration 120
# Iteration 120
# Iteration 121
# Iteration 120
# Iteration 121
# Iteration 121
# Iteration 122
# Iteration 121
# Iteration 122
# Iteration 122
# Iteration 123
# Iteration 122
# Iteration 123
# Iteration 123
# Iteration 124
# Iteration 123
# Iteration 124
# Iteration 124
# Iteration 124
# Iteration 125
# Iteration 125
# Iteration 125
# Iteration 126
# Iteration 125
# Iteration 126
# Iteration 126
# Iteration 127
# Iteration 126
# Iteration 127
# Iteration 128
# Iteration 127
# Iteration 127
# Iteration 128
# Iteration 128
# Iteration 129
# Iteration 128
# Iteration 129
# Iteration 129
# Iteration 130
# Iteration 129
# Iteration 130
# Iteration 130
# Iteration 131
# Iteration 130
# Iteration 131
# Iteration 131
# Iteration 132
# Iteration 131
# Iteration 132
# Iteration 132
# Iteration 132
# Iteration 133
# Iteration 133
# Iteration 133
# Iteration 134
# Iteration 133
# Iteration 134
# Iteration 134
# Iteration 135
# Iteration 134
# Iteration 135
# Iteration 136
# Iteration 135
# Iteration 135
# Iteration 136
# Iteration 136
# Iteration 137
# Iteration 136
# Iteration 137
# Iteration 137
# Iteration 138
# Iteration 137
# Iteration 138
# Iteration 138
# Iteration 139
# Iteration 138
# Iteration 139
# Iteration 139
# Iteration 140
# Iteration 139
# Iteration 140
# Iteration 140
# Iteration 140
# Iteration 141
# Iteration 141
# Iteration 141
# Iteration 142
# Iteration 141
# Iteration 142
# Iteration 142
# Iteration 143
# Iteration 142
# Iteration 143
# Iteration 143
# Iteration 144
# Iteration 143
# Iteration 144
# Iteration 144
# Iteration 144
# Iteration 145
# Iteration 145
# Iteration 145
# Iteration 146
# Iteration 145
# Iteration 146
# Iteration 146
# Iteration 146
# Iteration 147
# Iteration 147
# Iteration 147
# Iteration 148
# Iteration 147
# Iteration 148
# Iteration 148
# Iteration 148
# Iteration 149
# Iteration 149
# Iteration 149
# Iteration 150
# Iteration 149
# Iteration 150
# Iteration 150
# Iteration 151
# Iteration 150
# Iteration 151
# Iteration 152
# Iteration 151
# Iteration 151
# Iteration 152
# Iteration 152
# Iteration 153
# Iteration 152
# Iteration 153
# Iteration 153
# Iteration 154
# Iteration 153
# Iteration 154
# Iteration 154
# Iteration 155
# Iteration 154
# Iteration 155
# Iteration 155
# Iteration 156
# Iteration 155
# Iteration 156
# Iteration 156
# Iteration 156
# Iteration 157
# Iteration 157
# Iteration 157
# Iteration 158
# Iteration 157
# Iteration 158
# Iteration 158
# Iteration 159
# Iteration 158
# Iteration 159
# Iteration 160
# Iteration 159
# Iteration 159
# Iteration 160
# Iteration 160
# Iteration 161
# Iteration 160
# Iteration 161
# Iteration 161
# Iteration 162
# Iteration 161
# Iteration 162
# Iteration 162
# Iteration 163
# Iteration 162
# Iteration 163
# Iteration 163
# Iteration 164
# Iteration 163
# Iteration 164
# Iteration 164
# Iteration 164
# Iteration 165
# Iteration 165
# Iteration 165
# Iteration 166
# Iteration 165
# Iteration 166
# Iteration 166
# Iteration 167
# Iteration 166
# Iteration 167
# Iteration 168
# Iteration 167
# Iteration 167
# Iteration 168
# Iteration 168
# Iteration 169
# Iteration 168
# Iteration 169
# Iteration 169
# Iteration 170
# Iteration 169
# Iteration 170
# Iteration 170
# Iteration 171
# Iteration 170
# Iteration 171
# Iteration 171
# Iteration 172
# Iteration 171
# Iteration 172
# Iteration 172
# Iteration 172
# Iteration 173
# Iteration 173
# Iteration 173
# Iteration 174
# Iteration 173
# Iteration 174
# Iteration 174
# Iteration 175
# Iteration 174
# Iteration 175
# Iteration 176
# Iteration 175
# Iteration 175
# Iteration 176
# Iteration 176
# Iteration 176
# Iteration 177
# Iteration 177
# Iteration 177
# Iteration 177
# Iteration 178
# Iteration 178
# Iteration 178
# Iteration 178
# Iteration 179
# Iteration 179
# Iteration 179
# Iteration 180
# Iteration 179
# Iteration 180
# Iteration 180
# Iteration 180
# Iteration 181
# Iteration 181
# Iteration 181
# Iteration 182
# Iteration 181
# Iteration 182
# Iteration 182
# Iteration 183
# Iteration 182
# Iteration 183
# Iteration 184
# Iteration 183
# Iteration 183
# Iteration 184
# Iteration 184
# Iteration 184
# Iteration 185
# Iteration 185
# Iteration 185
# Iteration 186
# Iteration 185
# Iteration 186
# Iteration 186
# Iteration 186
# Iteration 187
# Iteration 187
# Iteration 187
# Iteration 188
# Iteration 187
# Iteration 188
# Iteration 188
# Iteration 188
# Iteration 189
# Iteration 189
# Iteration 189
# Iteration 190
# Iteration 189
# Iteration 190
# Iteration 190
# Iteration 191
# Iteration 190
# Iteration 191
# Iteration 192
# Iteration 191
# Iteration 191
# Iteration 192
# Iteration 192
# Iteration 193
# Iteration 192
# Iteration 193
# Iteration 193
# Iteration 194
# Iteration 193
# Iteration 194
# Iteration 194
# Iteration 195
# Iteration 194
# Iteration 195
# Iteration 196
# Iteration 195
# Iteration 195
# Iteration 196
# Iteration 196
# Iteration 196
# Iteration 197
# Iteration 197
# Iteration 198
# Iteration 197
# Iteration 197
# Iteration 198
# Iteration 198
# Iteration 199
# Iteration 198
# Iteration 199
# Iteration 200
# Iteration 199
# Iteration 199
# Iteration 200
# Iteration 200
# Iteration 200
# Iteration 201
# Iteration 201
# Iteration 201
# Iteration 201
# ✅ Chunk 1/4: 202 rows written
# ✅ Chunk 2/4: 202 rows written
# ✅ Chunk 3/4: 202 rows written
# ✅ Chunk 4/4: 202 rows written
# ✅ Results saved to /mnt/d/Mes Donnees/TCMP/github/ModFileGen/tests/output/9ff9a555-24ea-4956-becc-48db482b63d9_stics.csv
# STICS total time: 86.13s
#
# ============================================================
# ✅ STICS conversion completed successfully!
